# %%
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
import pandas as pd

# %%
# Question solving --1 

# l1 = [2, 4, 3]
# lenl1 = len(listt)
# add = 0
# count = 0
# for i in l1:
#     for j in range(count, lenl1):
#         add += i * (10 ** j)
#         break
#     count += 1
# # print(add)

# l2 = [5, 6, 4]
# lenl2 = len(l2)
# add2 = 0
# count2 = 0
# for i in l2:
#     for j in range(count2, lenl2):
#         add2 += i * (10 ** j)
#         break
#     count2 += 1

# addtion = add + add2

# nums = (list(str(addtion)))
# nums2 = nums[::-1]

# print(list(map(int ,nums2)))

# %%
# Question solving ---2 

# if __name__ == '__main__':
# n = int(input())
# # 'sham': [35.0, 35.0, 40.0], 'ram': [34.0, 45.0, 56.0], 'vijay': [23.0, 45.0, 66.0]
# student_marks = {}
# for _ in range(n):
#     name, *line = input().split()
#     scores = list(map(float, line))
#     student_marks[name] = scores
# query_name = input()
# sum_of_marks = 0
# for names in student_marks:
#     if query_name == names:
#         for i in student_marks[names]:
#             sum_of_marks += i
#         # print(sum_of_marks)

# avg_student = duble(sum_of_marks // len(student_marks[query_name]))
# print(avg_student)

# %%
import requests

# %%
# url = "https://jsonplaceholder.typicode.com/comments"

# response = requests.get(url)

# print(response.status_code)
# data = response.json()

# %%
# df = pd.json_normalize(data)

# %%
# with open("json02.data", "w") as f:
#     df.to_json(f, index=False)

# %%
# with open("json02.data", "r") as f:
#     data = f.read()

# %%
# data2 = pd.read_json("json02.data")

# %%
# data2.head(10)

# %%
# url2 ="https://quotes.toscrape.com/page/1/"
# response2 = requests.get(url2)
# print(response2.status_code)
# data4 = response2.json
# Out:
# 200

# %%
# data4
# Out:
# <bound method Response.json of <Response [200]>>

# %%
import requests

url = "https://quotes.toscrape.com/page/2/"

try:
    response = requests.get(url)
    print("Request sent successfully")
    print("Status Code:", response.status_code)
    data2 = response.text

except Exception as e:
    print("ERROR OCCURRED:")
    print(e)
# Out:
# Request sent successfully
# Status Code: 200

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
#
#
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
data2
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n    \n    \n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“This life is what you make it. No matter what, you&#39;re going to mess up sometimes, it&#39;s a universal truth. But th
# ...

# %%
# for i in range(1, 21):
#     link = f"https://quotes.toscrape.com/page/{i}/"
#     response = requests.get(link)

#     with open("scrape.html", "a", encoding="utf-8") as f:
#         f.write(f"\n\n<!-- PAGE {i} -->\n\n")
#         f.write(response.text)

#     print(f"Page {i} saved")
# Out:
# Page 1 saved
# Page 2 saved
# Page 3 saved
# Page 4 saved
# Page 5 saved
# Page 6 saved
# Page 7 saved
# Page 8 saved
# Page 9 saved
# Page 10 saved
# Page 11 saved
# Page 12 saved
# Page 13 saved
# Page 14 saved
# Page 15 saved
# Page 16 saved
# Page 17 saved
# Page 18 saved
# Page 19 saved
# Page 20 saved

# %%
from bs4 import BeautifulSoup

with open("scrape.html", "r", encoding = "utf-8") as f:
    html_data = f.read()
soup = BeautifulSoup(html_data, "html.parser")

# %%
# result = soup.find_all("small", class_= "author")
# author_name = []
# for a in result:
#     author_name.append(a.text)

spans = soup.find_all("span", class_= "text")
all_quotes = []

for s in spans:
    all_quotes.append(s.get_text(strip=True))
    # print(s.get_text(strip=True))

# %%
# author_name

# %%
all_quotes
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”",
#  '“Try not to become a man of success. Rather become a man of value.”',
#  '“It is better to be hated for what you are than to be loved for what you are not.”',
#  "“I have not failed. I've just found 10,000 ways that won't work.”",
#  "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”",
#  '“A day without sunshine is like, you know, night.”',
# ...

# %%
df = pd.DataFrame(all_quotes, author_name)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                                     0
# Albert Einstein     “The world as we have created it is a process ...
# J.K. Rowling        “It is our choices, Harry, that show what we t...
# Albert Einstein     “There are only two ways to live your life. On...
# Jane Austen         “The person, be it gentleman or lady, who has ...
# Marilyn Monroe      “Imperfection is beauty, madness is genius and...
# ...                                                               ...
# Harper Lee          “You never really understand a person until yo...
# Madeleine L'Engle   “You have to write the book that wants to be w...
# Mark Twain          “Never tell the truth to people who are not wo...
# Dr. Seuss                 “A person's a person, no matter how small.”
# George R.R. Martin  “... a mind needs books as a sword needs a whe...
#
# [100 rows x 1 columns]>
